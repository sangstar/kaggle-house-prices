# %%
import numpy as np
import json

# %%
with open('files/to_numerical.txt','r') as f:
    lines = f.readlines()

# %%
 lines = [line.rstrip() for line in lines]

# %%
lines
# Out:
# ['',
#  'LotShape: General shape of property',
#  '',
#  '       Reg\tRegular',
#  '       IR1\tSlightly irregular',
#  '       IR2\tModerately Irregular',
#  '       IR3\tIrregular',
#  '',
#  '',
#  'Utilities: Type of utilities available',
#  '',
#  '       AllPub\tAll public Utilities (E,G,W,& S)',
#  '       NoSewr\tElectricity, Gas, and Water (Septic Tank)',
#  '       NoSeWa\tElectricity and Gas Only',
#  '       ELO\tElectricity only',
#  '',
#  'LandSlope: Slope of property',
#  '',
#  '       Gtl\tGentle slope',
#  '       Mod\tModerate Slope',
#  '       Sev\tSevere Slope',
#  '',
#  '',
#  '',
#  'BsmtQual: Evaluates the height of the basement',
#  '',
#  '       Ex\tExcellent (100+ inches)',
#  '       Gd\tGood (90-99 inches)',
#  '       TA\tTypical (80-89 inches)',
#  '       Fa\tFair (70-79 inches)',
#  '       Po\tPoor (<70 inches',
#  '       NA\tNo Basement',
#  '',
#  'BsmtCond: Evaluates the general condition of the basement',
#  '',
#  '       Ex\tExcellent',
# ...

# %%
to_numerical = ['GarageFinish',
 'Functional',
 'GarageCond',
 'HeatingQC',
 'BsmtCond',
 'PoolQC',
 'KitchenQual',
 'Utilities',
 'ExterCond',
 'BsmtExposure',
 'ExterQual',
 'GarageQual',
 'Fence',
 'LotShape',
 'FireplaceQu',
 'LandSlope',
 'BsmtFinType1',
 'BsmtFinType2',
 'BsmtQual']

# %%
lines
# Out:
# ['',
#  'LotShape: General shape of property',
#  '',
#  '       Reg\tRegular',
#  '       IR1\tSlightly irregular',
#  '       IR2\tModerately Irregular',
#  '       IR3\tIrregular',
#  '',
#  '',
#  'Utilities: Type of utilities available',
#  '',
#  '       AllPub\tAll public Utilities (E,G,W,& S)',
#  '       NoSewr\tElectricity, Gas, and Water (Septic Tank)',
#  '       NoSeWa\tElectricity and Gas Only',
#  '       ELO\tElectricity only',
#  '',
#  'LandSlope: Slope of property',
#  '',
#  '       Gtl\tGentle slope',
#  '       Mod\tModerate Slope',
#  '       Sev\tSevere Slope',
#  '',
#  '',
#  '',
#  'BsmtQual: Evaluates the height of the basement',
#  '',
#  '       Ex\tExcellent (100+ inches)',
#  '       Gd\tGood (90-99 inches)',
#  '       TA\tTypical (80-89 inches)',
#  '       Fa\tFair (70-79 inches)',
#  '       Po\tPoor (<70 inches',
#  '       NA\tNo Basement',
#  '',
#  'BsmtCond: Evaluates the general condition of the basement',
#  '',
#  '       Ex\tExcellent',
# ...

# %%
i = 0
ordered_categories = []
while i < len(lines):
    #print(i, len(lines))
    line = lines[i]
    split_for_column_name = line.split(":")
    #print(split_for_column_name)
    if any([x in to_numerical for x in split_for_column_name]):
        to_add = []
        location_of_match = np.where([x in to_numerical for x in split_for_column_name])[0][0]
        col = split_for_column_name[location_of_match]
        #print(col)
        j = i
        while j+1 != len(lines) and not any([x in to_numerical for x in lines[j+1].split(":")]):
            categorical = lines[j].split("\t")
            to_add.append(categorical[0].replace(" ",''))
            j += 1
        i = j
    to_add = [x for x in to_add if x]
    ordered_categories.append((col, to_add[1:]))
    i += 1
# Out:
# 0 170
# ['']
# 1 170
# ['LotShape', ' General shape of property']
# 9 170
# ['Utilities', ' Type of utilities available']
# 16 170
# ['LandSlope', ' Slope of property']
# 24 170
# ['BsmtQual', ' Evaluates the height of the basement']
# 33 170
# ['BsmtCond', ' Evaluates the general condition of the basement']
# 42 170
# ['BsmtExposure', ' Refers to walkout or garden level walls']
# 50 170
# ['BsmtFinType1', ' Rating of basement finished area']
# 60 170
# ['BsmtFinType2', ' Rating of basement finished area (if multiple types)']
# 70 170
# ['HeatingQC', ' Heating quality and condition']
# 79 170
# ['KitchenQual', ' Kitchen quality']
# 88 170
# ['Functional', ' Home functionality (Assume typical unless deductions are warranted)']
# 100 170
# ['FireplaceQu', ' Fireplace quality']
# 110 170
# ['GarageFinish', ' Interior finish of the garage']
# 117 170
# ['ExterCond', ' Evaluates the present condition of the material on the exterior']
# 126 170
# ...

# %%
ordered_categories = dict(ordered_categories)

# %%
ordered_categories
# Out:
# {'Fence': ['GdPrv', 'MnPrv', 'GdWo', 'MnWw', 'NA'],
#  'LotShape': ['Reg', 'IR1', 'IR2', 'IR3'],
#  'Utilities': ['AllPub', 'NoSewr', 'NoSeWa', 'ELO'],
#  'LandSlope': ['Gtl', 'Mod', 'Sev'],
#  'BsmtQual': ['Ex', 'Gd', 'TA', 'Fa', 'Po', 'NA'],
#  'BsmtCond': ['Ex', 'Gd', 'TA', 'Fa', 'Po', 'NA'],
#  'BsmtExposure': ['Gd', 'Av', 'Mn', 'No', 'NA'],
#  'BsmtFinType1': ['GLQ', 'ALQ', 'BLQ', 'Rec', 'LwQ', 'Unf', 'NA'],
#  'BsmtFinType2': ['GLQ', 'ALQ', 'BLQ', 'Rec', 'LwQ', 'Unf', 'NA'],
#  'HeatingQC': ['Ex', 'Gd', 'TA', 'Fa', 'Po'],
#  'KitchenQual': ['Ex', 'Gd', 'TA', 'Fa', 'Po'],
#  'Functional': ['Typ', 'Min1', 'Min2', 'Mod', 'Maj1', 'Maj2', 'Sev', 'Sal'],
#  'FireplaceQu': ['Ex', 'Gd', 'TA', 'Fa', 'Po', 'NA'],
#  'GarageFinish': ['Fin', 'RFn', 'Unf', 'NA'],
#  'ExterCond': ['Ex', 'Gd', 'TA', 'Fa', 'Po'],
#  'ExterQual': ['Ex', 'Gd', 'TA', 'Fa', 'Po'],
#  'GarageQual': ['Ex', 'Gd', 'TA', 'Fa', 'Po', 'NA'],
#  'GarageCond': ['Ex', 'Gd', 'TA', 'Fa', 'Po', 'NA'],
# ...

# %%
with open('files/to_numerical_json.json', 'w') as f:
    json.dump(ordered_categories, f)

# %%
import pandas as pd 
pd.read_csv('files/test.csv')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...
